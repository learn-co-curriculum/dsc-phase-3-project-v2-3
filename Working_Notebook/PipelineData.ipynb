# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier, DummyRegressor
import numpy as np

# %%
df = pd.read_csv('../data/bigml_59c28831336c6604c800002a.csv')
df
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 0                yes                     25              265.1
# 1                yes                     26              161.6
# 2                 no                      0              243.4
# 3                 no                      0              299.4
# 4                 no                      0              166.7
# ...              ...                    ...                ...
# 3328             yes                     36              156.2
# 3329              no                      0              231.1
# 3330              no                      0              180.8
# 3331              no                      0              213.8
# 3332             yes                     25              234.4
#
#       total day calls  total day charge  ...  total eve calls  \
# 0                 110             45.07  ...               99
# 1                 123             27.47  ...              103
# 2                 114             41.38  ...              110
# 3                  71             50.90  ...               88
# 4                 113             28.34  ...              122
# ...               ...               ...  ...              ...
# 3328               77             26.55  ...              126
# 3329               57             39.29  ...               55
# 3330              109             30.74  ...               58
# 3331              105             36.35  ...               84
# 3332              113             39.85  ...               82
#
#       total eve charge  total night minutes  total night calls  \
# 0                16.78                244.7                 91
# 1                16.62                254.4                103
# 2                10.30                162.6                104
# 3                 5.26                196.9                 89
# 4                12.61                186.9                121
# ...                ...                  ...                ...
# 3328             18.32                279.1                 83
# 3329             13.04                191.3                123
# 3330             24.55                191.9                 91
# 3331             13.57                139.2                137
# 3332             22.60                241.4                 77
#
#       total night charge  total intl minutes  total intl calls  \
# 0                  11.01                10.0                 3
# 1                  11.45                13.7                 3
# 2                   7.32                12.2                 5
# 3                   8.86                 6.6                 7
# 4                   8.41                10.1                 3
# ...                  ...                 ...               ...
# 3328               12.56                 9.9                 6
# 3329                8.61                 9.6                 4
# 3330                8.64                14.1                 6
# 3331                6.26                 5.0                10
# 3332               10.86                13.7                 4
#
#       total intl charge  customer service calls  churn
# 0                  2.70                       1  False
# 1                  3.70                       1  False
# 2                  3.29                       0  False
# 3                  1.78                       2  False
# 4                  2.73                       3  False
# ...                 ...                     ...    ...
# 3328               2.67                       2  False
# 3329               2.59                       3  False
# 3330               3.81                       2  False
# 3331               1.35                       2  False
# 3332               3.70                       0  False
#
# [3333 rows x 21 columns]

# %%
df = df.drop(columns = ['phone number', 'area code'])

# %%
df['average_hourly_night_rate'] = df['total night minutes'] / df['total night charge']

# %%
df['average_hourly_day_rate'] = df['total day minutes'] / df['total day charge']

# %%
df['average_hourly_intl_rate'] = df['total intl minutes'] / df['total intl charge']

# %%
df['average_hourly_eve_rate'] = df['total eve minutes'] / df['total eve charge']

# %%
df['total_minutes'] = df['total night minutes'] + df['total day minutes'] + df['total intl minutes'] + df['total eve minutes']

# %%
df.dropna(axis=0, inplace=True)

# %%
X = df.drop('churn', axis=1)
y = df['churn']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
test_state_cat = X_test['state']

# %%
train_plan_ord = X_train[['international plan', 'voice mail plan']]

# %%
test_plan_ord = X_test[['international plan', 'voice mail plan']]

# %%
X_train
# Out:
#      state  account length international plan voice mail plan  \
# 228     VA             104                 no             yes
# 367     MD              45                 no              no
# 872     OK             149                 no             yes
# 1266    IA              42                 no              no
# 277     SD             144                 no             yes
# ...    ...             ...                ...             ...
# 1103    KS              52                 no              no
# 1138    MA              46                 no              no
# 1302    WA             171                 no              no
# 865     MD              52                 no              no
# 3193    IA              88                 no              no
#
#       number vmail messages  total day minutes  total day calls  \
# 228                      23              280.2              136
# 367                       0               78.2              127
# 872                      43              206.7               79
# 1266                      0              155.4              127
# 277                      48              189.8               96
# ...                     ...                ...              ...
# 1103                      0              165.5               78
# 1138                      0              139.4               81
# 1302                      0              270.5               69
# 865                       0              209.8              114
# 3193                      0              113.7               67
#
#       total day charge  total eve minutes  total eve calls  ...  \
# 228              47.63              220.5               92  ...
# 367              13.29              253.4              108  ...
# 872              35.14              174.6              122  ...
# 1266             26.42              164.1               45  ...
# 277              32.27              123.4               67  ...
# ...                ...                ...              ...  ...
# 1103             28.14              205.5               89  ...
# 1138             23.70              223.7              113  ...
# 1302             45.99              230.0              112  ...
# 865              35.67              171.3               82  ...
# 3193             19.33              165.1              127  ...
#
#       total night charge  total intl minutes  total intl calls  \
# 228                 6.16                13.3                 3
# 367                11.48                18.0                 3
# 872                10.87                10.9                 3
# 1266                7.10                 9.0                 3
# 277                 9.64                 6.5                 2
# ...                  ...                 ...               ...
# 1103                9.61                12.2                 6
# 1138                7.79                13.6                 6
# 1302                6.12                 9.6                 5
# 865                 6.96                 9.9                 9
# 3193                6.37                10.8                 3
#
#       total intl charge  customer service calls  average_hourly_night_rate  \
# 228                3.59                       4                  22.224026
# 367                4.86                       1                  22.212544
# 872                2.94                       1                  22.217111
# 1266               2.43                       0                  22.211268
# 277                1.76                       2                  22.219917
# ...                 ...                     ...                        ...
# 1103               3.29                       0                  22.226847
# 1138               3.67                       1                  22.220796
# 1302               2.59                       1                  22.222222
# 865                2.67                       4                  22.212644
# 3193               2.92                       1                  22.213501
#
#       average_hourly_day_rate  average_hourly_intl_rate  \
# 228                  5.882847                  3.704735
# 367                  5.884123                  3.703704
# 872                  5.882186                  3.707483
# 1266                 5.881908                  3.703704
# 277                  5.881624                  3.693182
# ...                       ...                       ...
# 1103                 5.881308                  3.708207
# 1138                 5.881857                  3.705722
# 1302                 5.881713                  3.706564
# 865                  5.881693                  3.707865
# 3193                 5.882049                  3.698630
#
#       average_hourly_eve_rate  total_minutes
# 228                 11.766275          650.9
# 367                 11.764160          604.6
# 872                 11.765499          633.7
# 1266                11.763441          486.2
# 277                 11.763584          533.9
# ...                       ...            ...
# 1103                11.763022          596.8
# 1138                11.767491          549.8
# 1302                11.764706          646.1
# 865                 11.765110          545.6
# 3193                11.767641          431.1
#
# [2484 rows x 23 columns]

# %%
#training_data
training_data.to_csv('training_data2.csv')

# %%
# testing_data
testing_data.to_csv('testing_data2.csv')

# %%
X_train
# Out:
#      state  account length international plan voice mail plan  \
# 228     VA             104                 no             yes
# 367     MD              45                 no              no
# 872     OK             149                 no             yes
# 1266    IA              42                 no              no
# 277     SD             144                 no             yes
# ...    ...             ...                ...             ...
# 1103    KS              52                 no              no
# 1138    MA              46                 no              no
# 1302    WA             171                 no              no
# 865     MD              52                 no              no
# 3193    IA              88                 no              no
#
#       number vmail messages  total day minutes  total day calls  \
# 228                      23              280.2              136
# 367                       0               78.2              127
# 872                      43              206.7               79
# 1266                      0              155.4              127
# 277                      48              189.8               96
# ...                     ...                ...              ...
# 1103                      0              165.5               78
# 1138                      0              139.4               81
# 1302                      0              270.5               69
# 865                       0              209.8              114
# 3193                      0              113.7               67
#
#       total day charge  total eve minutes  total eve calls  ...  \
# 228              47.63              220.5               92  ...
# 367              13.29              253.4              108  ...
# 872              35.14              174.6              122  ...
# 1266             26.42              164.1               45  ...
# 277              32.27              123.4               67  ...
# ...                ...                ...              ...  ...
# 1103             28.14              205.5               89  ...
# 1138             23.70              223.7              113  ...
# 1302             45.99              230.0              112  ...
# 865              35.67              171.3               82  ...
# 3193             19.33              165.1              127  ...
#
#       total night charge  total intl minutes  total intl calls  \
# 228                 6.16                13.3                 3
# 367                11.48                18.0                 3
# 872                10.87                10.9                 3
# 1266                7.10                 9.0                 3
# 277                 9.64                 6.5                 2
# ...                  ...                 ...               ...
# 1103                9.61                12.2                 6
# 1138                7.79                13.6                 6
# 1302                6.12                 9.6                 5
# 865                 6.96                 9.9                 9
# 3193                6.37                10.8                 3
#
#       total intl charge  customer service calls  average_hourly_night_rate  \
# 228                3.59                       4                  22.224026
# 367                4.86                       1                  22.212544
# 872                2.94                       1                  22.217111
# 1266               2.43                       0                  22.211268
# 277                1.76                       2                  22.219917
# ...                 ...                     ...                        ...
# 1103               3.29                       0                  22.226847
# 1138               3.67                       1                  22.220796
# 1302               2.59                       1                  22.222222
# 865                2.67                       4                  22.212644
# 3193               2.92                       1                  22.213501
#
#       average_hourly_day_rate  average_hourly_intl_rate  \
# 228                  5.882847                  3.704735
# 367                  5.884123                  3.703704
# 872                  5.882186                  3.707483
# 1266                 5.881908                  3.703704
# 277                  5.881624                  3.693182
# ...                       ...                       ...
# 1103                 5.881308                  3.708207
# 1138                 5.881857                  3.705722
# 1302                 5.881713                  3.706564
# 865                  5.881693                  3.707865
# 3193                 5.882049                  3.698630
#
#       average_hourly_eve_rate  total_minutes
# 228                 11.766275          650.9
# 367                 11.764160          604.6
# 872                 11.765499          633.7
# 1266                11.763441          486.2
# 277                 11.763584          533.9
# ...                       ...            ...
# 1103                11.763022          596.8
# 1138                11.767491          549.8
# 1302                11.764706          646.1
# 865                 11.765110          545.6
# 3193                11.767641          431.1
#
# [2484 rows x 23 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2484 entries, 228 to 3193
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      2484 non-null   object
#  1   account length             2484 non-null   int64
#  2   international plan         2484 non-null   object
#  3   voice mail plan            2484 non-null   object
#  4   number vmail messages      2484 non-null   int64
#  5   total day minutes          2484 non-null   float64
#  6   total day calls            2484 non-null   int64
#  7   total day charge           2484 non-null   float64
#  8   total eve minutes          2484 non-null   float64
#  9   total eve calls            2484 non-null   int64
#  10  total eve charge           2484 non-null   float64
#  11  total night minutes        2484 non-null   float64
#  12  total night calls          2484 non-null   int64
#  13  total night charge         2484 non-null   float64
#  14  total intl minutes         2484 non-null   float64
#  15  total intl calls           2484 non-null   int64
#  16  total intl charge          2484 non-null   float64
#  17  customer service calls     2484 non-null   int64
#  18  average_hourly_night_rate  2484 non-null   float64
#  19  average_hourly_day_rate    2484 non-null   float64
#  20  average_hourly_intl_rate   2484 non-null   float64
#  21  average_hourly_eve_rate    2484 non-null   float64
#  22  total_minutes              2484 non-null   float64
# dtypes: float64(13), int64(7), object(3)
# memory usage: 465.8+ KB
